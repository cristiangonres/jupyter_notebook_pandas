# %%
import pandas as pd

df = pd.read_csv('dataset/dataset.csv', index_col="id")

# %%
df
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df.head(3)
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129

# %%
df.tail(8)
# Out:
#                                                 full_text  favorites  \
# id
# 183740                        Programming is a hot topic!      133.0
# 183741                            Programming? i love it!       92.0
# 183742                                            WHAT???      255.0
# 183743                         Amazing video by Leonardo!      432.0
# 183744                                        Thanks man!      430.0
# 183745          There is nothing better than programming!      424.0
# 183746                                           BORED AF      488.0
# 183747  I do not know if i like programming or other t...      318.0
#
#         retweets  mentions  country             user  followers  followees
# id
# 183740     145.0      15.0   BRASIL       lucasperes       82.0        351
# 183741     146.0       1.0  ECUADOR     galocastillo      332.0        378
# 183742      73.0      17.0  ECUADOR     galocastillo      332.0        378
# ...

# %%
df.describe()
# Out:
#         favorites    retweets   mentions   followers    followees
# count   26.000000   26.000000  26.000000   26.000000    27.000000
# mean   280.538462   80.000000  15.423077  352.807692  1190.185185
# std    153.377242   40.303846   9.596554  375.319493  1965.735995
# min     23.000000   21.000000   1.000000   12.000000   129.000000
# 25%    139.250000   45.500000   8.250000   21.000000   258.000000
# 50%    305.500000   79.000000  16.000000  332.000000   351.000000
# 75%    422.500000  110.750000  23.500000  389.000000  1822.000000
# max    500.000000  146.000000  29.000000  982.000000  9918.000000

# %%
df.isna()
# Out:
#         full_text  favorites  retweets  mentions  country   user  followers  \
# id
# 183721      False      False      True     False    False  False      False
# 183722      False      False     False      True    False  False      False
# 183723      False      False     False     False    False  False      False
# 183724      False      False     False     False    False  False      False
# 183725      False      False     False     False    False  False      False
# 183726      False      False     False     False    False  False      False
# 183727      False      False     False     False    False  False      False
# 183728      False       True     False     False    False  False      False
# 183729      False      False     False     False    False  False      False
# 183730      False      False     False     False    False  False      False
# 183731      False      False     False     False    False  False      False
# ...

# %%
df.isna().count()
# Out:
# full_text    27
# favorites    27
# retweets     27
# mentions     27
# country      27
# user         27
# followers    27
# followees    27
# dtype: int64

# %%
df_filtrado = df.dropna()

# %%
df_filtrado.describe()
# Out:
#         favorites    retweets   mentions   followers    followees
# count   23.000000   23.000000  23.000000   23.000000    23.000000
# mean   275.695652   81.130435  15.347826  338.695652  1285.869565
# std    143.138025   38.275680   9.735636  369.501806  2101.492831
# min     43.000000   24.000000   1.000000   12.000000   129.000000
# 25%    145.500000   51.000000   7.000000   21.000000   258.000000
# 50%    296.000000   82.000000  17.000000  332.000000   378.000000
# 75%    389.500000  110.500000  23.000000  389.000000  1822.000000
# max    492.000000  146.000000  29.000000  982.000000  9918.000000

# %%
df_filtrado = df.fillna(0)

# %%
df_filtrado.head()
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       0.0      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       0.0   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 183725     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %%
df_filtrado = df.fillna({"retweets":666, "mentions":77})

# %%
df_filtrado.head(50)
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df["favorites"]
# Out:
# id
# 183721     23.0
# 183722    500.0
# 183723    190.0
# 183724    131.0
# 183725    113.0
# 183726    492.0
# 183727    158.0
# 183728      NaN
# 183729    198.0
# 183730    272.0
# 183731     43.0
# 183732    349.0
# 183733    467.0
# 183734     50.0
# 183735    418.0
# 183736    361.0
# 183737    346.0
# 183738    296.0
# 183739    315.0
# 183740    133.0
# 183741     92.0
# 183742    255.0
# 183743    432.0
# 183744    430.0
# 183745    424.0
# 183746    488.0
# 183747    318.0
# Name: favorites, dtype: float64

# %%
df[["favorites", "retweets"]]
# Out:
#         favorites  retweets
# id
# 183721       23.0       NaN
# 183722      500.0      21.0
# 183723      190.0     123.0
# 183724      131.0      76.0
# 183725      113.0     130.0
# 183726      492.0      70.0
# 183727      158.0      40.0
# 183728        NaN      50.0
# 183729      198.0      82.0
# 183730      272.0      92.0
# 183731       43.0     111.0
# 183732      349.0      44.0
# 183733      467.0      69.0
# 183734       50.0      24.0
# 183735      418.0      24.0
# 183736      361.0      92.0
# 183737      346.0     115.0
# 183738      296.0      93.0
# 183739      315.0      26.0
# 183740      133.0     145.0
# 183741       92.0     146.0
# 183742      255.0      73.0
# 183743      432.0      95.0
# 183744      430.0     143.0
# 183745      424.0     110.0
# 183746      488.0      28.0
# 183747      318.0      58.0

# %%
df.iloc[[0, 4, 6], 3:7]
# Out:
#         mentions  country           user  followers
# id
# 183721      10.0  ECUADOR  leonardokuffo      389.0
# 183725       9.0   MEXICO    pedrojuarez       12.0
# 183727      22.0  ECUADOR  leonardokuffo      389.0

# %%
df.iloc[[0, 4, 6]]
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183725                                    Welcome back! 🙌      113.0
# 183727                                 80's & friends! ✈️      158.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183725     130.0       9.0   MEXICO    pedrojuarez       12.0        129
# 183727      40.0      22.0  ECUADOR  leonardokuffo      389.0        258

# %%
df.loc[183725 : 183727, ["favorites", "full_text"]]
# Out:
#         favorites                                          full_text
# id
# 183725      113.0                                    Welcome back! 🙌
# 183726      492.0  Contest: Win a fan of his ass. #thatisall Thanks!
# 183727      158.0                                 80's & friends! ✈️

# %%
df
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df[(df["favorites"] < 200.0) & (df["country"].str.contains("ECUADOR"))]
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183727                                 80's & friends! ✈️      158.0
# 183734                             I cannot believe this!       50.0
# 183741                            Programming? i love it!       92.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 183727      40.0      22.0  ECUADOR  leonardokuffo      389.0        258
# 183734      24.0      22.0  ECUADOR  leonardokuffo      389.0        258
# 183741     146.0       1.0  ECUADOR   galocastillo      332.0        378

# %%
import random
def calcular(retweets):
    return retweets * random.randint(3, 5)

df["ganancias"] = df["retweets"].apply(calcular)

# %%
df["ganancias"]
# Out:
# id
# 183721      NaN
# 183722     63.0
# 183723    369.0
# 183724    304.0
# 183725    520.0
# 183726    280.0
# 183727    200.0
# 183728    200.0
# 183729    410.0
# 183730    460.0
# 183731    444.0
# 183732    132.0
# 183733    345.0
# 183734     96.0
# 183735    120.0
# 183736    368.0
# 183737    575.0
# 183738    465.0
# 183739    130.0
# 183740    580.0
# 183741    584.0
# 183742    365.0
# 183743    475.0
# 183744    715.0
# 183745    440.0
# 183746     84.0
# 183747    290.0
# Name: ganancias, dtype: float64

# %%
df
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
def popularidad(fila):
    resultado = fila["followees"] / fila["followers"]
    return resultado

popu = df["popular"] = df.apply(popularidad, axis = 1)

# %%
df
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df.groupby("country").mean({"followers": 'sum', "mentions": 'mean',
                           "retweets":'max'})
# Out:
#           favorites   retweets  mentions  followers    followees
# country
# BRASIL   339.909091  91.272727    19.600    616.600  1889.363636
# ECUADOR  186.375000  64.857143    11.875    360.500   318.000000
# MEXICO   294.857143  77.750000    13.750     15.375  1101.000000

# %%
df.groupby("country").agg({"followers": 'sum', "mentions": 'mean',
                           "retweets":'max'})
# Out:
#          followers  mentions  retweets
# country
# BRASIL      6166.0    19.600     145.0
# ECUADOR     2884.0    11.875     146.0
# MEXICO       123.0    13.750     130.0

# %%
agrupado = df.groupby("country").agg({"followers": 'sum', "mentions": 'mean',
                           "retweets":'max'})
agrupado[agrupado["followers"] > 5000]
# Out:
#          followers  mentions  retweets
# country
# BRASIL      6166.0      19.6     145.0

# %%
import matplotlib.pyplot as plt
agrupado["followers"].plot()
# Out:
# <AxesSubplot: xlabel='country'>

# %%
popu.plot()
# Out:
# <AxesSubplot: xlabel='id'>

# %%
df["popular"].plot(kind="bar")
plt.show()

# %%
df.plot(kind="scatter", x= "favorites", y="retweets")
# Out:
# <AxesSubplot: xlabel='favorites', ylabel='retweets'>

# %%
agrupado.to_csv("salida.csv")

# %%
data = [
    {
        "columna1": 1,
        "columna2": 1123
    },
    {
        "columna1": 54,
        "columna2": 56
    }
]

df2 = pd.DataFrame(data)
df2
# Out:
#    columna1  columna2
# 0         1      1123
# 1        54        56
